# %%
# %run ../00-setup/00_config

# %%
import requests
import json

url = "https://en.wikipedia.org/w/api.php?action=sitematrix&format=json"
headers = {"User-Agent": f"{PROJECT_NAME}/1.0"}

response = requests.get(url, headers=headers)
response.raise_for_status()

raw_json_data = response.text

landing_file_path = f"{LANDING_REFERENCE_PATH}/sitematrix_raw.json"

dbutils.fs.put(landing_file_path, raw_json_data, overwrite=True)
